# %% [markdown]
# ### Imports and Data Load

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import sklearn.metrics as metrics 
from sklearn.preprocessing import MinMaxScaler

# %%
training_data = pd.read_csv('/home/ec2-user/capstone/broadband-capstone/data/broadband_training_bin_2.csv')
test_data = pd.read_csv('/home/ec2-user/capstone/broadband-capstone/data/broadband_test_bin_2.csv')

# %% [markdown]
# ## Variable Selection

# %% [markdown]
# ### Splitting up Categorical and Numerical Variables

# %%
numeric_features = list(training_data.columns.values[(training_data.dtypes=='float64') | (training_data.dtypes=='int')])
categorical_features = list(training_data.columns.values[~((training_data.dtypes=='float64') | (training_data.dtypes=='int'))])

# %%
numeric_features
# Out:
# ['tract_geoid',
#  'All_Provider_Count',
#  'MaxAdDown',
#  'MaxAdUp',
#  'Wired_Provider_Count',
#  'Satellite_Provider_Count',
#  'Fixed_Wireless_Provider_Count',
#  'All_Provider_Count_25',
#  'All_Provider_Count_100',
#  'Fixed_Wireless_Provider_Count_25',
#  'Wired_Provider_Count_25',
#  'Satellite_Provider_Count_25',
#  'Fixed_Wireless_Provider_Count_100',
#  'Wired_Provider_Count_100',
#  'Satellite_Provider_Count_100',
#  'median_age_overall',
#  'median_age_male',
#  'median_age_female',
#  'state',
#  'county',
#  'tract',
#  'employment_rate',
#  'median_income',
#  'total_households',
#  'ave_household_size',
#  'ave_family_size',
#  'pct_health_ins_children',
#  'pct_health_ins_19_64',
#  'pct_health_ins_65+',
#  'total_population',
#  'median_house_value',
#  'pct_white',
#  'pct_hisp_latino',
#  'pct_black',
#  'pct_native',
#  'pct_asian',
#  'pct_hi_pi',
#  'pct_other_race',
#  'pct_two+_race',
#  'pct_rent_burdened',
#  'poverty_rate',
#  'pct_pop_bachelors+',
#  'pct_pop_hs+',
#  'pct_internet',
#  'pct_internet_dial_up',
#  'pct_internet_broadband_any_type',
#  'pct_internet_cellular',
#  'pct_only_cellular',
#  'pct_internet_broadband_fiber',
#  'pct_internet_broadband_satellite',
#  'pct_internet_only_satellite',
#  'pct_internet_other',
#  'pct_internet_no_subscrp',
#  'pct_internet_none',
#  'pct_computer',
#  'pct_computer_with_dialup',
#  'pct_computer_with_broadband',
#  'pct_computer_no_internet',
#  'pct_no_computer',
#  'ALAND',
#  'AWATER',
#  'ALAND_SQMI',
#  'AWATER_SQMI',
#  'population_density',
#  'pct_pop_ged',
#  'pct_pop_some_college',
#  'pct_pop_associates',
#  'pct_pop_ssi_households',
#  'pct_pop_lt_10k',
#  'pct_pop_10k_thru_15k',
#  'pct_pop_15k_thru_20k',
#  'pct_pop_20k_thru_25k',
#  'pct_pop_25k_thru_30k',
#  'pct_pop_30k_thru_35k',
#  'pct_pop_35k_thru_40k',
#  'pct_pop_40k_thru_45k',
#  'pct_pop_45k_thru_50k',
#  'pct_pop_50k_thru_60k',
#  'pct_pop_60k_thru_75k',
#  'pct_pop_75k_thru_100k',
#  'pct_pop_100k_thru_125k',
#  'pct_pop_125k_thru_150k',
#  'pct_pop_150k_thru_200k',
#  'pct_pop_gt_200k',
#  'pct_pop_lt_5',
#  'pct_pop_5_to_9',
#  'pct_pop_10_to_14',
#  'pct_pop_15_to_19',
#  'pct_pop_20_to_24',
#  'pct_pop_25_to_29',
#  'pct_pop_30_to_34',
#  'pct_pop_35_to_39',
#  'pct_pop_40_to_44',
#  'pct_pop_45_to_49',
#  'pct_pop_50_to_54',
#  'pct_pop_55_to_59',
#  'pct_pop_60_to_64',
#  'pct_pop_65_to_69',
#  'pct_pop_70_to_74',
#  'pct_pop_75_to_79',
#  'pct_pop_80_to_84',
#  'pct_pop_gt_85',
#  'pct_pop_disability',
#  'pct_pop_households_with_kids',
#  'pct_pop_foreign_born',
#  'Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
#  'Form 477 All Terrestrial Broadband: Max Advertised Consumer Upload Speed (Mbps)',
#  'Ookla Median Download Speed (Mbps)',
#  'Ookla Median Upload Speed (Mbps)',
#  'Primary RUCA Code 2010',
#  'Secondary RUCA Code, 2010 (see errata)',
#  '0_5_providers',
#  '6_10_providers',
#  '11_15_providers',
#  '16_20_providers',
#  '20+_providers',
#  '0_25_MaxAdDown',
#  '25_99_MaxAdDown',
#  '99_499_MaxAdDown',
#  '499_inf_MaxAdDown',
#  '0_25_Ookla Median Download Speed (Mbps)',
#  '25_99_Ookla Median Download Speed (Mbps)',
#  '99_499_Ookla Median Download Speed (Mbps)',
#  '499_inf_Ookla Median Download Speed (Mbps)',
#  '0_25_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
#  '25_99_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
#  '99_499_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
#  '499_inf_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
#  'single_provider',
#  'Primary RUCA Code - 1.0',
#  'Primary RUCA Code - 2.0',
#  'Primary RUCA Code - 4.0',
#  'Primary RUCA Code - 10.0',
#  'Primary RUCA Code - 7.0',
#  'Primary RUCA Code - 5.0',
#  'Primary RUCA Code - 8.0',
#  'Primary RUCA Code - 3.0',
#  'Primary RUCA Code - 6.0',
#  'Primary RUCA Code - 9.0',
#  'Primary RUCA Code - 99.0',
#  'Secondary RUCA Code - 1.0',
#  'Secondary RUCA Code - 2.0',
#  'Secondary RUCA Code - 4.0',
#  'Secondary RUCA Code - 10.0',
#  'Secondary RUCA Code - 7.0',
#  'Secondary RUCA Code - 5.0',
#  'Secondary RUCA Code - 1.1',
#  'Secondary RUCA Code - 8.0',
#  'Secondary RUCA Code - 3.0',
#  'Secondary RUCA Code - 6.0',
#  'Secondary RUCA Code - 9.0',
#  'Secondary RUCA Code - 4.1',
#  'Secondary RUCA Code - 99.0',
#  'Secondary RUCA Code - 7.1',
#  'Secondary RUCA Code - 10.2',
#  'Secondary RUCA Code - 2.1',
#  'Secondary RUCA Code - 10.1',
#  'Secondary RUCA Code - 10.3',
#  'Secondary RUCA Code - 7.2',
#  'Secondary RUCA Code - 5.1',
#  'Secondary RUCA Code - 8.1',
#  'Secondary RUCA Code - 8.2']

# %%
broadband_vars = ['MaxAdDown',
                 'MaxAdUp',
                 'Wired_Provider_Count',
                 'Satellite_Provider_Count',
                 'Fixed_Wireless_Provider_Count',
                 'All_Provider_Count_25',
                 'All_Provider_Count_100',
                 'Fixed_Wireless_Provider_Count_25',
                 'Wired_Provider_Count_25',
                 'Satellite_Provider_Count_25',
                 'Fixed_Wireless_Provider_Count_100',
                 'Wired_Provider_Count_100',
                 'Satellite_Provider_Count_100',
                 'pct_internet',
                 'pct_internet_dial_up',
                 'pct_internet_broadband_any_type',
                 'pct_internet_cellular',
                 'pct_only_cellular',
                 'pct_internet_broadband_fiber',
                 'pct_internet_broadband_satellite',
                 'pct_internet_only_satellite',
                 'pct_internet_other',
                 'pct_internet_no_subscrp',
                 'pct_internet_none',
                 'pct_computer',
                 'pct_computer_with_dialup',
                 'pct_computer_with_broadband',
                 'pct_computer_no_internet',
                 'pct_no_computer',
                 'Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
                 'Form 477 All Terrestrial Broadband: Max Advertised Consumer Upload Speed (Mbps)',
                 'Ookla Median Download Speed (Mbps)',
                 'Ookla Median Upload Speed (Mbps)',
                 '0_5_providers',
                 '6_10_providers',
                 '11_15_providers',
                 '16_20_providers',
                 '20+_providers',
                 '0_25_MaxAdDown',
                 '25_99_MaxAdDown',
                 '99_499_MaxAdDown',
                 '499_inf_MaxAdDown',
                 '0_25_Ookla Median Download Speed (Mbps)',
                 '25_99_Ookla Median Download Speed (Mbps)',
                 '99_499_Ookla Median Download Speed (Mbps)',
                 '499_inf_Ookla Median Download Speed (Mbps)',
                 '0_25_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
                 '25_99_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
                 '99_499_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
                 '499_inf_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
                 'single_provider',
                 'Primary RUCA Code - 1.0',
                 'Primary RUCA Code - 2.0',
                 'Primary RUCA Code - 4.0',
                 'Primary RUCA Code - 10.0',
                 'Primary RUCA Code - 7.0',
                 'Primary RUCA Code - 5.0',
                 'Primary RUCA Code - 8.0',
                 'Primary RUCA Code - 3.0',
                 'Primary RUCA Code - 6.0',
                 'Primary RUCA Code - 9.0',
                 'Primary RUCA Code - 99.0',
                 'Secondary RUCA Code - 1.0',
                 'Secondary RUCA Code - 2.0',
                 'Secondary RUCA Code - 4.0',
                 'Secondary RUCA Code - 10.0',
                 'Secondary RUCA Code - 7.0',
                 'Secondary RUCA Code - 5.0',
                 'Secondary RUCA Code - 1.1',
                 'Secondary RUCA Code - 8.0',
                 'Secondary RUCA Code - 3.0',
                 'Secondary RUCA Code - 6.0',
                 'Secondary RUCA Code - 9.0',
                 'Secondary RUCA Code - 4.1',
                 'Secondary RUCA Code - 99.0',
                 'Secondary RUCA Code - 7.1',
                 'Secondary RUCA Code - 10.2',
                 'Secondary RUCA Code - 2.1',
                 'Secondary RUCA Code - 10.1',
                 'Secondary RUCA Code - 10.3',
                 'Secondary RUCA Code - 7.2',
                 'Secondary RUCA Code - 5.1',
                 'Secondary RUCA Code - 8.1',
                 'Secondary RUCA Code - 8.2',
                 'SE',
                 'INFA',
                 'DDI',
                 'ruca_metro',
                 'ruca_micro',
                 'ruca_small_town',
                 'ruca_rural',
                 'Comcast_present',
                 'ATT_present',
                 'HughesNet_present',
                 'GCI_Comm_Corp_present',
                 'ViaSat_present',
                 'VSAT_present',
                 'Century_Link_present',
                 'Spectrum_present',
                 'Crown_Castle_present',
                 'Etheric_present',
                 'Frontier_Communications_present']

# %% [markdown]
# ### Remove the dependent variable

# %%
numeric_features.remove('poverty_rate')

# %% [markdown]
# ### Check which variables are highly correlated with the dependent variables

# %%
pearson_corr = training_data.corr('pearson')

# %%
pearson_corr['poverty_rate'].abs().sort_values(ascending=False)[50:100]
# Out:
# pct_pop_associates                                                                           0.200645
# pct_pop_40k_thru_45k                                                                         0.188437
# pct_pop_households_with_kids                                                                 0.179496
# total_population                                                                             0.174081
# pct_pop_75_to_79                                                                             0.173279
# pct_pop_5_to_9                                                                               0.172689
# pct_pop_15_to_19                                                                             0.171785
# pct_pop_60k_thru_75k                                                                         0.160678
# pct_pop_40_to_44                                                                             0.151943
# Ookla Median Upload Speed (Mbps)                                                             0.147822
# pct_pop_80_to_84                                                                             0.144345
# pct_health_ins_children                                                                      0.137186
# pct_asian                                                                                    0.134776
# 99_499_Ookla Median Download Speed (Mbps)                                                    0.134471
# pct_pop_gt_85                                                                                0.127163
# All_Provider_Count_100                                                                       0.124603
# population_density                                                                           0.119736
# All_Provider_Count_25                                                                        0.118012
# Ookla Median Download Speed (Mbps)                                                           0.116799
# Wired_Provider_Count_100                                                                     0.115016
# pct_pop_45k_thru_50k                                                                         0.113749
# pct_health_ins_65+                                                                           0.112179
# 25_99_Ookla Median Download Speed (Mbps)                                                     0.108702
# pct_native                                                                                   0.108282
# Wired_Provider_Count_25                                                                      0.102062
# pct_internet_broadband_fiber                                                                 0.099893
# Primary RUCA Code - 4.0                                                                      0.094052
# Secondary RUCA Code - 4.0                                                                    0.093965
# Primary RUCA Code - 2.0                                                                      0.092727
# Secondary RUCA Code - 2.0                                                                    0.091565
# pct_internet_broadband_satellite                                                             0.086293
# pct_pop_some_college                                                                         0.072305
# All_Provider_Count                                                                           0.071194
# Fixed_Wireless_Provider_Count_25                                                             0.070197
# 499_inf_MaxAdDown                                                                            0.068342
# pct_pop_30_to_34                                                                             0.067284
# MaxAdDown                                                                                    0.066151
# 499_inf_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)    0.062250
# Fixed_Wireless_Provider_Count_100                                                            0.062151
# MaxAdUp                                                                                      0.061257
# county                                                                                       0.061177
# 99_499_MaxAdDown                                                                             0.060837
# pct_pop_35_to_39                                                                             0.057372
# pct_pop_10_to_14                                                                             0.057266
# Wired_Provider_Count                                                                         0.056359
# Primary RUCA Code - 7.0                                                                      0.055248
# 6_10_providers                                                                               0.054365
# Secondary RUCA Code - 7.0                                                                    0.053061
# 99_499_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)     0.051149
# Primary RUCA Code 2010                                                                       0.050171
# Name: poverty_rate, dtype: float64

# %% [markdown]
# Poverty rate is obviously correlated with income levels. These will end up diluting the effect of the variables we're actually interested in studying. We'll drop variables related to income levels and other similar indicators. Similarly, there are other variables related to housing which should be dropped, and demographic information which shouldn't be relevant.

# %%
income_variables = ['pct_pop_lt_10k',
                    'pct_pop_ssi_households',
                    'pct_pop_10k_thru_15k',
                    'median_income',
                    'pct_pop_15k_thru_20k',
                    'pct_pop_150k_thru_200k',
                    'pct_pop_100k_thru_125k',
                    'pct_pop_125k_thru_150k',
                    'pct_pop_20k_thru_25k',
                    'pct_pop_75k_thru_100k',
                    'pct_pop_gt_200k',
                    'pct_pop_25k_thru_30k',
                    'pct_pop_30k_thru_35k',
                    'pct_pop_35k_thru_40k',
                    'pct_pop_40k_thru_45k',
                    'pct_pop_60k_thru_75k',
                    'pct_pop_45k_thru_50k',
                    'pct_pop_50k_thru_60k']

housing_variables = ['pct_rent_burdened',
                     'median_house_value']

# %%
for i in income_variables:
    numeric_features.remove(i)
    
for i in housing_variables:
    numeric_features.remove(i)

# %% [markdown]
# ### Drop other variables which have been made into dummy variables

# %%
dummy_variables = ['MaxAdDown',
                   'Ookla Median Download Speed (Mbps)',
                   'Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
                   'Primary RUCA Code 2010',
                   'Secondary RUCA Code, 2010 (see errata)']

for i in dummy_variables:
    numeric_features.remove(i)

# %%
numeric_features
# Out:
# ['tract_geoid',
#  'All_Provider_Count',
#  'MaxAdDown',
#  'MaxAdUp',
#  'Wired_Provider_Count',
#  'Satellite_Provider_Count',
#  'Fixed_Wireless_Provider_Count',
#  'All_Provider_Count_25',
#  'All_Provider_Count_100',
#  'Fixed_Wireless_Provider_Count_25',
#  'Wired_Provider_Count_25',
#  'Satellite_Provider_Count_25',
#  'Fixed_Wireless_Provider_Count_100',
#  'Wired_Provider_Count_100',
#  'Satellite_Provider_Count_100',
#  'median_age_overall',
#  'median_age_male',
#  'median_age_female',
#  'state',
#  'county',
#  'tract',
#  'employment_rate',
#  'total_households',
#  'ave_household_size',
#  'ave_family_size',
#  'pct_health_ins_children',
#  'pct_health_ins_19_64',
#  'pct_health_ins_65+',
#  'total_population',
#  'pct_white',
#  'pct_hisp_latino',
#  'pct_black',
#  'pct_native',
#  'pct_asian',
#  'pct_hi_pi',
#  'pct_other_race',
#  'pct_two+_race',
#  'pct_pop_bachelors+',
#  'pct_pop_hs+',
#  'pct_internet',
#  'pct_internet_dial_up',
#  'pct_internet_broadband_any_type',
#  'pct_internet_cellular',
#  'pct_only_cellular',
#  'pct_internet_broadband_fiber',
#  'pct_internet_broadband_satellite',
#  'pct_internet_only_satellite',
#  'pct_internet_other',
#  'pct_internet_no_subscrp',
#  'pct_internet_none',
#  'pct_computer',
#  'pct_computer_with_dialup',
#  'pct_computer_with_broadband',
#  'pct_computer_no_internet',
#  'pct_no_computer',
#  'ALAND',
#  'AWATER',
#  'ALAND_SQMI',
#  'AWATER_SQMI',
#  'population_density',
#  'pct_pop_ged',
#  'pct_pop_some_college',
#  'pct_pop_associates',
#  'pct_pop_lt_5',
#  'pct_pop_5_to_9',
#  'pct_pop_10_to_14',
#  'pct_pop_15_to_19',
#  'pct_pop_20_to_24',
#  'pct_pop_25_to_29',
#  'pct_pop_30_to_34',
#  'pct_pop_35_to_39',
#  'pct_pop_40_to_44',
#  'pct_pop_45_to_49',
#  'pct_pop_50_to_54',
#  'pct_pop_55_to_59',
#  'pct_pop_60_to_64',
#  'pct_pop_65_to_69',
#  'pct_pop_70_to_74',
#  'pct_pop_75_to_79',
#  'pct_pop_80_to_84',
#  'pct_pop_gt_85',
#  'pct_pop_disability',
#  'pct_pop_households_with_kids',
#  'pct_pop_foreign_born',
#  'Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
#  'Form 477 All Terrestrial Broadband: Max Advertised Consumer Upload Speed (Mbps)',
#  'Ookla Median Download Speed (Mbps)',
#  'Ookla Median Upload Speed (Mbps)',
#  'Primary RUCA Code 2010',
#  'Secondary RUCA Code, 2010 (see errata)',
#  '0_5_providers',
#  '6_10_providers',
#  '11_15_providers',
#  '16_20_providers',
#  '20+_providers',
#  '0_25_MaxAdDown',
#  '25_99_MaxAdDown',
#  '99_499_MaxAdDown',
#  '499_inf_MaxAdDown',
#  '0_25_Ookla Median Download Speed (Mbps)',
#  '25_99_Ookla Median Download Speed (Mbps)',
#  '99_499_Ookla Median Download Speed (Mbps)',
#  '499_inf_Ookla Median Download Speed (Mbps)',
#  '0_25_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
#  '25_99_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
#  '99_499_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
#  '499_inf_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
#  'single_provider',
#  'Primary RUCA Code - 1.0',
#  'Primary RUCA Code - 2.0',
#  'Primary RUCA Code - 4.0',
#  'Primary RUCA Code - 10.0',
#  'Primary RUCA Code - 7.0',
#  'Primary RUCA Code - 5.0',
#  'Primary RUCA Code - 8.0',
#  'Primary RUCA Code - 3.0',
#  'Primary RUCA Code - 6.0',
#  'Primary RUCA Code - 9.0',
#  'Primary RUCA Code - 99.0',
#  'Secondary RUCA Code - 1.0',
#  'Secondary RUCA Code - 2.0',
#  'Secondary RUCA Code - 4.0',
#  'Secondary RUCA Code - 10.0',
#  'Secondary RUCA Code - 7.0',
#  'Secondary RUCA Code - 5.0',
#  'Secondary RUCA Code - 1.1',
#  'Secondary RUCA Code - 8.0',
#  'Secondary RUCA Code - 3.0',
#  'Secondary RUCA Code - 6.0',
#  'Secondary RUCA Code - 9.0',
#  'Secondary RUCA Code - 4.1',
#  'Secondary RUCA Code - 99.0',
#  'Secondary RUCA Code - 7.1',
#  'Secondary RUCA Code - 10.2',
#  'Secondary RUCA Code - 2.1',
#  'Secondary RUCA Code - 10.1',
#  'Secondary RUCA Code - 10.3',
#  'Secondary RUCA Code - 7.2',
#  'Secondary RUCA Code - 5.1',
#  'Secondary RUCA Code - 8.1',
#  'Secondary RUCA Code - 8.2']

# %% [markdown]
# ### Normalize features

# %% [markdown]
# To compare features in the model more easily, let's normalize the features. Some, like location based metrics and dummy variables should not be normalized.

# %%
do_not_normalize = [ 'tract_geoid', 
                     'state', 
                     'county', 
                     'tract',
                     '0_5_providers',
                     '6_10_providers',
                     '11_15_providers',
                     '16_20_providers',
                     '20+_providers',
                     '0_25_MaxAdDown',
                     '25_99_MaxAdDown',
                     '99_499_MaxAdDown',
                     '499_inf_MaxAdDown',
                     '0_25_Ookla Median Download Speed (Mbps)',
                     '25_99_Ookla Median Download Speed (Mbps)',
                     '99_499_Ookla Median Download Speed (Mbps)',
                     '499_inf_Ookla Median Download Speed (Mbps)',
                     '0_25_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
                     '25_99_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
                     '99_499_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
                     '499_inf_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
                     'single_provider',
                     'Primary RUCA Code - 1.0',
                     'Primary RUCA Code - 2.0',
                     'Primary RUCA Code - 4.0',
                     'Primary RUCA Code - 10.0',
                     'Primary RUCA Code - 7.0',
                     'Primary RUCA Code - 5.0',
                     'Primary RUCA Code - 8.0',
                     'Primary RUCA Code - 3.0',
                     'Primary RUCA Code - 6.0',
                     'Primary RUCA Code - 9.0',
                     'Primary RUCA Code - 99.0',
                     'Secondary RUCA Code - 1.0',
                     'Secondary RUCA Code - 2.0',
                     'Secondary RUCA Code - 4.0',
                     'Secondary RUCA Code - 10.0',
                     'Secondary RUCA Code - 7.0',
                     'Secondary RUCA Code - 5.0',
                     'Secondary RUCA Code - 1.1',
                     'Secondary RUCA Code - 8.0',
                     'Secondary RUCA Code - 3.0',
                     'Secondary RUCA Code - 6.0',
                     'Secondary RUCA Code - 9.0',
                     'Secondary RUCA Code - 4.1',
                     'Secondary RUCA Code - 99.0',
                     'Secondary RUCA Code - 7.1',
                     'Secondary RUCA Code - 10.2',
                     'Secondary RUCA Code - 2.1',
                     'Secondary RUCA Code - 10.1',
                     'Secondary RUCA Code - 10.3',
                     'Secondary RUCA Code - 7.2',
                     'Secondary RUCA Code - 5.1',
                     'Secondary RUCA Code - 8.1',
                     'Secondary RUCA Code - 8.2']

normalize = list(set(numeric_features)-set(do_not_normalize))

# %%
scaler = MinMaxScaler()
train_df_norm = pd.DataFrame(scaler.fit_transform(training_data[normalize]), columns = normalize)
test_df_norm = pd.DataFrame(scaler.fit_transform(test_data[normalize]), columns = normalize)

# %%
training_df_normalized = train_df_norm.join(training_data[do_not_normalize])
test_df_normalized = test_df_norm.join(test_data[do_not_normalize])

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Functions

# %%
def regression_results(y_true, y_pred):

    # Regression metrics
    explained_variance=metrics.explained_variance_score(y_true, y_pred)
    mean_absolute_error=metrics.mean_absolute_error(y_true, y_pred) 
    mse=metrics.mean_squared_error(y_true, y_pred) 
    median_absolute_error=metrics.median_absolute_error(y_true, y_pred)
    r2=metrics.r2_score(y_true, y_pred)

    print('explained_variance: ', round(explained_variance,4))    
    print('r2: ', round(r2,4))
    print('MAE: ', round(mean_absolute_error,4))
    print('MSE: ', round(mse,4))
    print('RMSE: ', round(np.sqrt(mse),4))

# %%
poverty_rate_train = np.array(training_data['poverty_rate'])
poverty_rate_test = np.array(test_data['poverty_rate'])

def poverty_model(train_df, 
                  test_df, 
                  variable_list,
                  poverty_rate_train = poverty_rate_train,  
                  poverty_rate_test = poverty_rate_test):
    
    #Convert to numpy array
    train_variables = np.array(train_df[variable_list])
    test_variables = np.array(test_df[variable_list])
    
    #Fit train and test variables
    model = LinearRegression().fit(train_variables, poverty_rate_train)
    predicted = model.predict(test_variables)
    
    #Use regression results function to score the model
    regression_results(poverty_rate_test, predicted)
    
    #Print how important features in the model are
    print("\n")
    coefficients = pd.DataFrame()
    coefficients['variable'] = variable_list
    coefficients['coef'] = model.coef_
    coefficients['abs_coef'] = np.absolute(model.coef_)

    coefficients.sort_values(by="abs_coef", ascending=False, inplace=True)
    
    for i in range(len(coefficients)):
        print (f"{coefficients['variable'].iloc[i]}: {coefficients['coef'].iloc[i]}")
    
    return True

# %% [markdown]
# ### All Variables

# %%
poverty_model(train_df = training_data,
              test_df = test_data, 
              variable_list = numeric_features)
# Out:
# explained_variance:  0.7596
# r2:  0.7596
# MAE:  3.9688
# MSE:  28.7982
# RMSE:  5.3664
#
#
# AWATER_SQMI: -106.30579378718409
# ALAND_SQMI: -63.994996674789746
# ave_household_size: -2.9140398436752517
# Satellite_Provider_Count_25: 1.7366248823423969
# ave_family_size: -1.2323172687826582
# 0_5_providers: -1.2176054126378955
# Secondary RUCA Code - 8.2: -1.1995026585786492
# Satellite_Provider_Count: 1.08386991832925
# Wired_Provider_Count_25: 0.9009548841533771
# Primary RUCA Code - 1.0: 0.839664776308757
# 25_99_MaxAdDown: -0.7554729577310748
# Wired_Provider_Count_100: -0.7292357324443173
# All_Provider_Count_25: -0.7153852211927701
# Secondary RUCA Code - 10.1: 0.691028788729306
# Satellite_Provider_Count_100: -0.6730135834421656
# Primary RUCA Code - 8.0: -0.654982685477608
# Primary RUCA Code - 9.0: -0.6255314399614875
# Secondary RUCA Code - 9.0: -0.6255314398407413
# Fixed_Wireless_Provider_Count_25: 0.6160338757893956
# pct_pop_20_to_24: 0.6137504912839084
# Secondary RUCA Code - 1.1: 0.5727538175646881
# pct_pop_gt_85: -0.5655595022032616
# pct_pop_80_to_84: -0.55391350373175
# pct_pop_10_to_14: 0.5437748094284949
# pct_pop_5_to_9: 0.5428348246386658
# 499_inf_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): 0.0708319986353115
# pct_internet_dial_up: -0.06996263304440259
# pct_internet_broadband_any_type: 0.06878959074915636
# pct_pop_60_to_64: -0.06567501408071846
# 25_99_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): -0.06504325392228298
# pct_computer: -0.06497538993144303
# pct_no_computer: 0.06497531233384246
# pct_pop_55_to_59: -0.06425604947686953
# median_age_male: -0.05647611864657169
# pct_health_ins_children: 0.056474707291734594
# Secondary RUCA Code - 4.1: 0.055981894951412106
# pct_health_ins_65+: -0.05070949297644292
# 99_499_MaxAdDown: 0.04812211535528023
# Primary RUCA Code - 2.0: 0.04686383645660733
# pct_internet_only_satellite: -0.04318387215898506
# pct_internet_other: 0.04119704784308279
# pct_internet_cellular: -0.040168263971949836
# pct_pop_bachelors+: 0.040030223969987025
# pct_computer_with_dialup: -0.039271216454811735
# pct_pop_30_to_34: 0.03559801184919109
# 99_499_Ookla Median Download Speed (Mbps): -0.03129388526761749
# pct_pop_some_college: -0.02984536739408966
# pct_pop_foreign_born: 0.024456440997834283
# 99_499_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): -0.022669040873843055
# 0_25_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): 0.01688029751380463
# pct_internet_broadband_fiber: -0.015020521517960628
# Ookla Median Upload Speed (Mbps): -0.014904391730430122
# pct_internet_no_subscrp: 0.009262699335384872
# pct_internet_none: -0.00808996664708761
# pct_pop_ged: -0.006241926250266122
# total_households: 0.002615311619179217
# county: -0.002244845884880331
# total_population: -0.0012323550728588761
# pct_internet: -0.0011726840322620058
# MaxAdUp: -0.00012595794850072826
# Form 477 All Terrestrial Broadband: Max Advertised Consumer Upload Speed (Mbps): 8.121444929060084e-05
# AWATER: 4.10450176201449e-05
# ALAND: 2.470855136715855e-05
# state: 2.122822204186914e-06
# tract: -6.39118839011743e-07
# population_density: 3.548633638050802e-07
# 499_inf_Ookla Median Download Speed (Mbps): 8.657674577250418e-11
# single_provider: 7.446199212779447e-11
# tract_geoid: -2.3720228833141236e-11
# Secondary RUCA Code - 99.0: 0.0
# Primary RUCA Code - 99.0: 0.0
# True

# %% [markdown]
# ### All Variables Normalized

# %%
poverty_model(train_df = training_df_normalized,  
              test_df = test_df_normalized, 
              variable_list = numeric_features)
# Out:
# explained_variance:  0.7272
# r2:  0.5104
# MAE:  6.1546
# MSE:  58.6576
# RMSE:  7.6588
#
#
# total_population: -88.66561935365111
# total_households: 55.424956958517186
# pct_pop_20_to_24: 36.29799969001547
# employment_rate: -35.122110956800256
# pct_pop_gt_85: -29.27428347913621
# pct_native: 22.79407389822046
# pct_black: 22.378741197784727
# pct_hisp_latino: 20.17546377528216
# median_age_overall: 19.641008048729706
# pct_asian: 19.271916553140095
# pct_white: 16.56719095939555
# pct_pop_households_with_kids: -16.0628684085726
# ave_household_size: -15.974340732243832
# pct_pop_80_to_84: -15.2431106293831
# pct_pop_70_to_74: -14.766204622468264
# Secondary RUCA Code - 1.1: 0.5748892367393346
# Primary RUCA Code - 4.0: 0.5213902761043911
# Secondary RUCA Code - 10.3: -0.5167269323282628
# Primary RUCA Code - 10.0: 0.5101148241504976
# 20+_providers: -0.4797509617946911
# Secondary RUCA Code - 10.2: 0.46806925776066194
# Secondary RUCA Code - 4.0: 0.4654655370941825
# 499_inf_MaxAdDown: 0.4379568195819881
# 25_99_Ookla Median Download Speed (Mbps): 0.42936990159159905
# Secondary RUCA Code - 2.1: 0.425741826155559
# 0_25_Ookla Median Download Speed (Mbps): -0.3983813403346872
# Secondary RUCA Code - 2.0: -0.3787624973148116
# Secondary RUCA Code - 8.1: 0.3499212648701573
# Secondary RUCA Code - 6.0: -0.3328412285098423
# Primary RUCA Code - 6.0: -0.33284122850960074
# Primary RUCA Code - 5.0: -0.3228579299234795
# pct_pop_bachelors+: 0.30215098657123884
# pct_internet_no_subscrp: -0.271094041095552
# Secondary RUCA Code - 1.0: 0.2667954652335389
# Secondary RUCA Code - 7.2: 0.26361224921537496
# 0_25_MaxAdDown: 0.2338758507731523
# Secondary RUCA Code - 5.1: -0.2169370940059131
# pct_computer_with_dialup: -0.21589601818372062
# Secondary RUCA Code - 8.0: 0.2016874931387065
# Secondary RUCA Code - 7.1: -0.20165905983133414
# Primary RUCA Code - 7.0: 0.1748012055471806
# 16_20_providers: -0.1713289695067015
# Primary RUCA Code - 3.0: -0.1531647649815433
# Secondary RUCA Code - 3.0: -0.15316476498108678
# Secondary RUCA Code - 10.0: -0.13870493246112725
# MaxAdUp: -0.1263089929828296
# Secondary RUCA Code - 7.0: 0.11284801616427487
# 11_15_providers: -0.1070991262323453
# Secondary RUCA Code - 5.0: -0.10592083591696877
# 6_10_providers: -0.09913591482597783
# 25_99_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): -0.07214126140035049
# 499_inf_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): 0.06793200615539571
# 99_499_MaxAdDown: 0.0649714280759035
# Secondary RUCA Code - 4.1: 0.05592473901047601
# Primary RUCA Code - 2.0: 0.04697932883997602
# state: -0.0459804837652662
# 0_25_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): 0.03148283952016229
# 99_499_Ookla Median Download Speed (Mbps): -0.03098856125824767
# 99_499_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): -0.02727358427592895
# county: -0.00229104874600905
# tract: -6.393847282737397e-07
# tract_geoid: 2.226634398962053e-11
# single_provider: 5.400124791776761e-13
# 499_inf_Ookla Median Download Speed (Mbps): 4.618527782440651e-14
# Primary RUCA Code - 99.0: 0.0
# Secondary RUCA Code - 99.0: 0.0
# True

# %% [markdown]
# Normalizing doesn't appear to have helped the model. In fact, it decreased the R^2 by 0.2 and increased other error metrics.

# %% [markdown]
# ## Splitting out Rich areas and Poor areas

# %%
training_data['median_income'].describe()
# Out:
# count     56671.000000
# mean      67277.815214
# std       33209.157458
# min        4129.000000
# 25%       44638.000000
# 50%       59848.000000
# 75%       81911.500000
# max      250001.000000
# Name: median_income, dtype: float64

# %%
rich_training_data = training_data[training_data['median_income'] > 67277.815214]
rich_test_data = test_data[test_data['median_income'] > 67277.815214]

poor_training_data = training_data[training_data['median_income'] < 67277.815214]
poor_test_data = test_data[test_data['median_income'] < 67277.815214]

# %%
poverty_model(train_df = rich_training_data, 
              test_df = rich_test_data, 
              variable_list = numeric_features,
              poverty_rate_train = np.array(rich_training_data['poverty_rate']),  
              poverty_rate_test =  np.array(rich_test_data['poverty_rate']))
# Out:
# explained_variance:  0.3928
# r2:  0.3928
# MAE:  2.3277
# MSE:  9.9761
# RMSE:  3.1585
#
#
# AWATER_SQMI: 43.811352206495286
# ALAND_SQMI: 20.84118181003962
# 0_25_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): -4.69113989585748
# 0_25_MaxAdDown: 4.2893958117307
# 0_5_providers: -1.9464792192758136
# 25_99_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): 1.7838155688139432
# ave_family_size: -1.7831650771395609
# 499_inf_MaxAdDown: -1.7365528524722378
# 499_inf_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): 1.5736758896460286
# 99_499_MaxAdDown: -1.509364220987219
# Satellite_Provider_Count_25: 1.3988507343865153
# 99_499_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): 1.3336484373998185
# Secondary RUCA Code - 7.2: 1.319526924796193
# 25_99_MaxAdDown: -1.0434787382731545
# Satellite_Provider_Count: -0.8409261227484429
# ave_household_size: -0.8178807225115557
# Secondary RUCA Code - 10.1: 0.7324426615320566
# pct_hi_pi: 0.5955455170611764
# Primary RUCA Code - 9.0: -0.5590874619418691
# Secondary RUCA Code - 9.0: -0.5590874619417996
# Wired_Provider_Count_100: -0.544890578074919
# Secondary RUCA Code - 7.0: -0.5001873945753136
# Primary RUCA Code - 7.0: 0.4984961607937105
# Secondary RUCA Code - 10.2: -0.4879108985092236
# pct_two+_race: 0.4849133626050477
# pct_other_race: 0.4698471018128928
# pct_hisp_latino: 0.46741048901923954
# pct_black: 0.4574073709252833
# pct_native: 0.4498600015294816
# pct_white: 0.4393654593605211
# pct_asian: 0.4384469200284136
# Secondary RUCA Code - 8.1: 0.3974781940200607
# Satellite_Provider_Count_100: -0.3909633332587968
# All_Provider_Count_100: 0.38863938529914865
# Wired_Provider_Count_25: 0.3862831044992741
# Secondary RUCA Code - 7.1: -0.32084336942569075
# Secondary RUCA Code - 2.0: -0.30086205231232876
# Secondary RUCA Code - 10.3: -0.2977898257359508
# Primary RUCA Code - 8.0: 0.2693679550008837
# 0_25_Ookla Median Download Speed (Mbps): -0.2659247486936546
# Secondary RUCA Code - 2.1: 0.2642965002136705
# All_Provider_Count_25: -0.24743666540532167
# pct_pop_20_to_24: 0.2354797472532123
# All_Provider_Count: -0.21886240986610764
# Wired_Provider_Count: 0.21114147054257607
# Fixed_Wireless_Provider_Count: 0.196802222783182
# pct_computer_with_broadband: 0.012368455424831004
# pct_pop_ged: -0.012125908291214675
# 11_15_providers: -0.009713398245639304
# pct_pop_35_to_39: -0.008672853273335036
# pct_pop_50_to_54: -0.007780257112309452
# pct_pop_some_college: -0.0067247221622041276
# pct_internet_none: 0.006570944231137021
# Ookla Median Upload Speed (Mbps): -0.005866430376017792
# pct_internet_broadband_fiber: 0.004640224393502701
# Secondary RUCA Code - 4.0: 0.003600674368020719
# Ookla Median Download Speed (Mbps): -0.0030571001954768917
# county: -0.000683797402676569
# total_households: 0.0005780386519531888
# total_population: -0.0002667016673441446
# MaxAdDown: 0.00014813314402886316
# Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): 7.571626898711381e-05
# MaxAdUp: 5.9822401376768435e-05
# Form 477 All Terrestrial Broadband: Max Advertised Consumer Upload Speed (Mbps): -5.406848291172883e-05
# AWATER: -1.6915536644346307e-05
# ALAND: -8.046969073083332e-06
# state: 1.0948184339517816e-06
# tract: -3.618040548339363e-07
# population_density: 1.320177143715462e-07
# tract_geoid: -1.5326353801316867e-11
# single_provider: -4.2668299449211133e-13
# 499_inf_Ookla Median Download Speed (Mbps): -4.178879464689089e-13
# Secondary RUCA Code - 99.0: 0.0
# Primary RUCA Code - 99.0: 0.0
# Secondary RUCA Code - 8.2: 0.0
# True

# %%
poverty_model(train_df = poor_training_data, 
              test_df = poor_test_data, 
              variable_list = numeric_features,
              poverty_rate_train = np.array(poor_training_data['poverty_rate']),  
              poverty_rate_test =  np.array(poor_test_data['poverty_rate']))
# Out:
# explained_variance:  0.6955
# r2:  0.6954
# MAE:  4.6139
# MSE:  36.7527
# RMSE:  6.0624
#
#
# AWATER_SQMI: -137.83779033712932
# ALAND_SQMI: -71.64377000639278
# ave_household_size: -2.111747036837482
# Satellite_Provider_Count: 2.061474737321052
# Satellite_Provider_Count_25: 1.512649687995052
# 0_25_MaxAdDown: -1.4063554142535677
# Secondary RUCA Code - 8.2: -1.3484292319222388
# ave_family_size: -1.1479246941024712
# 499_inf_MaxAdDown: 1.0910676714122798
# Secondary RUCA Code - 10.2: 1.0330969118959819
# Wired_Provider_Count_25: 0.9095664277041907
# Primary RUCA Code - 10.0: 0.904117820166079
# 0_5_providers: -0.8404251342489617
# All_Provider_Count_25: -0.7351030934959085
# Secondary RUCA Code - 2.0: -0.7061825401675365
# Primary RUCA Code - 1.0: 0.6953200487596501
# pct_pop_5_to_9: 0.6849102228792907
# pct_pop_10_to_14: 0.667614187920555
# pct_pop_20_to_24: 0.6612365749370162
# 20+_providers: -0.6598117224974827
# pct_pop_lt_5: 0.6381949889500034
# Fixed_Wireless_Provider_Count_25: 0.6358249570461558
# pct_pop_80_to_84: -0.6263437235448543
# 99_499_MaxAdDown: 0.609336878214897
# pct_pop_gt_85: -0.6083397608492622
# Primary RUCA Code - 8.0: -0.5939053799837731
# Satellite_Provider_Count_100: -0.5928714566393192
# Secondary RUCA Code - 10.3: -0.5831675690898297
# 0_25_Ookla Median Download Speed (Mbps): -0.5760653500079649
# pct_internet_broadband_satellite: -0.09856581562848926
# Secondary RUCA Code, 2010 (see errata): -0.09813619131320231
# pct_health_ins_19_64: -0.09688986475632438
# pct_pop_60_to_64: -0.0937254194926348
# pct_only_cellular: 0.0866066165586522
# pct_pop_associates: -0.08319860079984864
# pct_hi_pi: 0.07872390349869225
# pct_computer_no_internet: 0.07759907028191759
# pct_white: 0.07318683815867277
# pct_pop_bachelors+: 0.06183302596488416
# pct_health_ins_65+: -0.05957275542299281
# pct_no_computer: 0.05856978656067657
# pct_computer: -0.058569743346121306
# pct_pop_hs+: -0.05799130152345566
# pct_pop_55_to_59: -0.05777180369832903
# pct_health_ins_children: 0.05495860779081213
# pct_internet_broadband_any_type: 0.051450919166705966
# pct_other_race: 0.049606222273553546
# pct_pop_some_college: -0.044247508770949184
# pct_internet_dial_up: -0.04358640534394811
# pct_internet_cellular: -0.040702991229152496
# Primary RUCA Code 2010: -0.04015919009180245
# pct_pop_foreign_born: 0.03950525802326818
# Secondary RUCA Code - 10.0: 0.03196641132494245
# pct_pop_30_to_34: 0.026598424878539764
# pct_internet_other: -0.020240732195843075
# pct_internet_none: -0.018288738852920927
# pct_internet_only_satellite: -0.017321453359602668
# Ookla Median Upload Speed (Mbps): -0.014909290306601097
# median_age_male: -0.014428521482615517
# pct_internet_no_subscrp: 0.01042421581695463
# Ookla Median Download Speed (Mbps): -0.008069283866069837
# pct_internet: 0.007864486074430854
# pct_pop_ged: 0.007621769738334334
# pct_computer_with_dialup: -0.006451440514422056
# pct_internet_broadband_fiber: -0.006010336188690513
# total_households: 0.004007478095433087
# county: -0.0029740946728486345
# total_population: -0.001960492694761784
# state: -0.001397511851146116
# Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): 0.0004030993246568748
# MaxAdDown: -0.00031940625005578223
# Form 477 All Terrestrial Broadband: Max Advertised Consumer Upload Speed (Mbps): -0.00029226734717135994
# MaxAdUp: 0.00024191718433388864
# AWATER: 5.321963130966445e-05
# ALAND: 2.7661777555754163e-05
# tract: -4.7133452325820446e-07
# population_density: 4.3952423529197704e-07
# tract_geoid: -1.9837725316629944e-11
# 499_inf_Ookla Median Download Speed (Mbps): 5.671976777144039e-12
# single_provider: -9.328093852900565e-13
# Primary RUCA Code - 99.0: 0.0
# Secondary RUCA Code - 99.0: 0.0
# True

# %% [markdown]
# Splitting into rich and poor based on median hurt the model significantly! Keep the whole dataset.

# %% [markdown]
# ## Filtering to California Data

# %%
cali_train_data = training_data[training_data.state == 6]
cali_test_data = test_data[test_data.state == 6]

# %%
poverty_model(train_df = cali_train_data, 
              test_df = cali_test_data, 
              variable_list = numeric_features,
              poverty_rate_train = np.array(cali_train_data['poverty_rate']),  
              poverty_rate_test =  np.array(cali_test_data['poverty_rate']))
# Out:
# explained_variance:  0.7507
# r2:  0.7506
# MAE:  3.7145
# MSE:  24.4698
# RMSE:  4.9467
#
#
# AWATER_SQMI: -207.39103747159226
# ALAND_SQMI: -116.53799704745003
# Secondary RUCA Code - 8.1: 9.462175541236368
# Primary RUCA Code - 3.0: 0.1597660840294354
# pct_pop_hs+: -0.15835346562228447
# pct_only_cellular: 0.15522075091162002
# pct_two+_race: 0.14912962888501188
# pct_pop_25_to_29: 0.14842844087618492
# pct_pop_households_with_kids: -0.14557072689974165
# pct_native: 0.1452934009906136
# Secondary RUCA Code, 2010 (see errata): -0.14285500735214463
# pct_hisp_latino: 0.14187151521802535
# 99_499_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): 0.14180439679821913
# median_age_male: -0.1304650900225057
# Secondary RUCA Code - 1.1: 0.13013000881752357
# pct_pop_45_to_49: -0.1291061163707406
# pct_health_ins_65+: -0.11751592870149685
# 11_15_providers: 0.11289473574589096
# Primary RUCA Code - 4.0: 0.11138427203959775
# pct_computer_no_internet: 0.11105211890445843
# pct_pop_55_to_59: -0.10812167026376493
# Primary RUCA Code - 1.0: 0.1041398398575903
# pct_pop_15_to_19: 0.10248069031551155
# pct_pop_65_to_69: -0.09972321879085266
# Wired_Provider_Count: -0.09521620614092695
# pct_pop_40_to_44: -0.0848347048082152
# pct_pop_60_to_64: -0.07929451226933157
# pct_pop_50_to_54: -0.07545654950810535
# pct_pop_bachelors+: 0.06734105286690761
# pct_internet_broadband_fiber: 0.05620084226895297
# pct_pop_35_to_39: -0.05405558175788189
# pct_computer_with_dialup: 0.05127716635765932
# pct_internet_only_satellite: -0.04985987115172519
# pct_internet_no_subscrp: -0.044931010914476155
# pct_pop_associates: -0.03942026767036422
# pct_internet_cellular: 0.03702329587802655
# pct_health_ins_children: 0.036264669567769844
# pct_internet: 0.03590766194257666
# pct_internet_broadband_satellite: -0.03218942821040516
# pct_pop_30_to_34: 0.03164578257413703
# pct_computer: -0.03145243918270733
# pct_no_computer: 0.03145243915420149
# pct_internet_dial_up: 0.029069285438887135
# Secondary RUCA Code - 1.0: -0.025990168974087277
# pct_pop_foreign_born: 0.017930399852399137
# Secondary RUCA Code - 7.2: -0.013037178904058698
# MaxAdDown: -0.011434219232554563
# Ookla Median Upload Speed (Mbps): -0.010890826454793334
# pct_pop_some_college: -0.009568441070354206
# Primary RUCA Code - 10.0: -0.009033646643168317
# pct_internet_none: 0.009023348891296079
# pct_internet_broadband_any_type: 0.006838376845457517
# Ookla Median Download Speed (Mbps): -0.005894111504204824
# total_households: 0.0023166074250345267
# total_population: -0.0009567889222563547
# MaxAdUp: 0.0005018237751997443
# Satellite_Provider_Count: -0.0003108453277324468
# Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): 0.00023564901772621383
# state: 9.195989816296324e-05
# AWATER: 8.006712100072644e-05
# ALAND: 4.4995279191994975e-05
# Satellite_Provider_Count_25: 4.118274746084394e-05
# Form 477 All Terrestrial Broadband: Max Advertised Consumer Upload Speed (Mbps): -1.185426360583719e-05
# county: -4.13816088292579e-06
# tract: -1.5343554694534356e-06
# population_density: 6.579292816111248e-07
# tract_geoid: -1.2966689123526659e-08
# 0_5_providers: 4.195421787756004e-12
# 0_25_MaxAdDown: 1.1688428003253648e-12
# 499_inf_Ookla Median Download Speed (Mbps): 7.411848912397545e-13
# 0_25_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): 2.8421709430404007e-13
# Secondary RUCA Code - 99.0: 0.0
# Secondary RUCA Code - 7.1: 0.0
# Secondary RUCA Code - 9.0: 0.0
# Primary RUCA Code - 99.0: 0.0
# single_provider: 0.0
# Secondary RUCA Code - 5.1: 0.0
# Primary RUCA Code - 9.0: 0.0
# True

# %% [markdown]
# Narrowing to Cali data decreased the r2 value, but not by very much. It did decrease RMSE slightly, so this is a better model. One worry that I have is overfitting, since this dataset is less than 10x the size of the overall dataset.

# %%
poverty_model(train_df = cali_train_data, 
              test_df = cali_test_data, 
              variable_list = broadband_vars,
              poverty_rate_train = np.array(cali_train_data['poverty_rate']),  
              poverty_rate_test =  np.array(cali_test_data['poverty_rate']))
# Out:
# explained_variance:  0.6156
# r2:  0.6151
# MAE:  4.4129
# MSE:  37.7597
# RMSE:  6.1449
#
#
# Secondary RUCA Code - 8.1: 8.935299375945494
# 499_inf_MaxAdDown: 7.064865261217412
# Secondary RUCA Code - 8.0: -6.5233972108467135
# Secondary RUCA Code - 10.2: 4.573145716207579
# 99_499_MaxAdDown: -3.897288785801129
# Etheric_present: -3.3342111911048034
# 25_99_MaxAdDown: -3.1675764754162046
# Secondary RUCA Code - 7.2: -2.78895229725338
# Secondary RUCA Code - 10.3: -2.7551156722496146
# Wired_Provider_Count_100: -2.124910600310719
# All_Provider_Count_100: 1.9337488347620522
# Primary RUCA Code - 8.0: 1.8870564544788302
# Primary RUCA Code - 7.0: -1.7602850048643182
# Frontier_Communications_present: -1.4321404365036976
# Secondary RUCA Code - 10.0: -1.264636975489642
# Secondary RUCA Code - 1.1: -1.2329784928882104
# Fixed_Wireless_Provider_Count_100: -1.1996971754833372
# Wired_Provider_Count_25: 1.060683486038329
# Secondary RUCA Code - 7.0: 1.0286672923890436
# 20+_providers: 1.009388784249823
# Secondary RUCA Code - 1.0: 0.9946568364332398
# Secondary RUCA Code - 6.0: 0.8758148573768754
# Primary RUCA Code - 6.0: 0.8758148573768709
# Century_Link_present: 0.8613718875770482
# Secondary RUCA Code - 10.1: -0.7511655267498349
# All_Provider_Count_25: -0.7376425735327098
# Satellite_Provider_Count_100: -0.7352022718058067
# Secondary RUCA Code - 5.0: -0.7231377771896953
# Primary RUCA Code - 5.0: -0.723137777189689
# Secondary RUCA Code - 4.0: 0.7182744274837153
# 25_99_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): -0.7141581427893835
# Spectrum_present: -0.6375006469467281
# Crown_Castle_present: -0.6274230000367949
# Secondary RUCA Code - 4.1: -0.5972733016502907
# Secondary RUCA Code - 8.2: -0.5248457106199399
# ATT_present: -0.5013450311869718
# SE: 0.4420606158154612
# Fixed_Wireless_Provider_Count_25: 0.43223133627858545
# pct_computer_no_internet: 0.3585668937084425
# 499_inf_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): 0.3575720692075727
# 99_499_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): 0.35658607358182326
# pct_only_cellular: 0.3454859357562685
# 16_20_providers: -0.3217991568886167
# 25_99_Ookla Median Download Speed (Mbps): 0.3203831577927491
# pct_internet_other: 0.3085875206559241
# pct_computer_with_dialup: -0.29344722830641334
# ruca_micro: 0.2736782060206062
# pct_internet_only_satellite: 0.266508886671573
# Secondary RUCA Code - 2.1: -0.2568273801021281
# 99_499_Ookla Median Download Speed (Mbps): -0.24156231623094598
# Primary RUCA Code - 1.0: -0.23832165645492853
# INFA: -0.2352213012857864
# 11_15_providers: -0.22814316149595817
# pct_internet_broadband_satellite: -0.21982708379074922
# ruca_metro: -0.2026771973535767
# ruca_rural: -0.19777245828151035
# Primary RUCA Code - 10.0: -0.19777245828150924
# Secondary RUCA Code - 2.0: 0.17840785468379516
# DDI: 0.14572979335126257
# pct_computer_with_broadband: -0.13589216155929051
# ruca_small_town: 0.1267714496145046
# Primary RUCA Code - 4.0: 0.1210011258334297
# Wired_Provider_Count: 0.11605234926609445
# pct_internet_dial_up: -0.1154306786503656
# Primary RUCA Code - 3.0: 0.11406398451965427
# Secondary RUCA Code - 3.0: 0.11406398451965155
# pct_internet: -0.08997302536106622
# 0_25_Ookla Median Download Speed (Mbps): -0.07882084156178981
# Primary RUCA Code - 2.0: -0.07841952541832908
# Fixed_Wireless_Provider_Count: -0.07487091938151352
# pct_no_computer: 0.07077249615727577
# pct_computer: -0.07077249615724956
# pct_internet_cellular: 0.060305264460172925
# Comcast_present: -0.05304163211860363
# pct_internet_none: 0.04542612398453505
# pct_internet_no_subscrp: 0.04454690137673145
# pct_internet_broadband_fiber: 0.04359813958643799
# Ookla Median Upload Speed (Mbps): -0.04152325603319118
# pct_internet_broadband_any_type: 0.02545765328915328
# MaxAdDown: -0.01745466257793163
# Ookla Median Download Speed (Mbps): 0.016890381074743055
# 6_10_providers: -0.01686792849323343
# Form 477 All Terrestrial Broadband: Max Advertised Consumer Upload Speed (Mbps): 0.0006043736981486969
# Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): -0.0002371197338124631
# MaxAdUp: -8.478463778443558e-05
# Satellite_Provider_Count: 1.397770788003072e-13
# Satellite_Provider_Count_25: -2.4868995751603507e-14
# 0_25_Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps): 3.9968028886505635e-15
# 0_5_providers: -3.3306690738754696e-15
# single_provider: -2.6645352591003757e-15
# 0_25_MaxAdDown: -2.1094237467877974e-15
# 499_inf_Ookla Median Download Speed (Mbps): 8.881784197001252e-16
# Primary RUCA Code - 9.0: -3.3306690738754696e-16
# HughesNet_present: 0.0
# GCI_Comm_Corp_present: 0.0
# ViaSat_present: 0.0
# VSAT_present: 0.0
# Secondary RUCA Code - 5.1: 0.0
# Primary RUCA Code - 99.0: 0.0
# Secondary RUCA Code - 9.0: 0.0
# Secondary RUCA Code - 99.0: 0.0
# Secondary RUCA Code - 7.1: 0.0
# True
