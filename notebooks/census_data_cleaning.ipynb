# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Overview of this Notebook
#
# This notebook is meant to be run on the data output of running the Data Gathering notebook in the census scripts folder which produced a csv file of census variable columns (such as B01002_001E, B01002_002E, etc...) for each census tract in the US.
#
# The list of variables we pulled is here: https://docs.google.com/document/d/1eslJJ1DKmmNkJAtZbOdxHAbHCZ34L6cb2tkgMoExPwc/edit?usp=sharing

# %%
data = pd.read_csv("../data/census_data_old.csv")
data
# Out:
#                                                 NAME  B01003_001E  \
# 0         Census Tract 11, Jefferson County, Alabama         4781
# 1         Census Tract 14, Jefferson County, Alabama         1946
# 2         Census Tract 20, Jefferson County, Alabama         4080
# 3      Census Tract 38.02, Jefferson County, Alabama         5291
# 4         Census Tract 40, Jefferson County, Alabama         2533
# ...                                              ...          ...
# 73051    Census Tract 19.02, Laramie County, Wyoming         4187
# 73052  Census Tract 9808.01, Laramie County, Wyoming            0
# 73053    Census Tract 16.02, Natrona County, Wyoming         7513
# 73054    Census Tract 16.03, Natrona County, Wyoming         3724
# 73055        Census Tract 9651, Park County, Wyoming         5287
#
#        B01002_001E  B01002_002E  B01002_003E  B15003_001E  B15003_017E  \
# 0             39.0         42.5         38.1         3285          552
# ...

# %%
data.columns
# Out:
# Index(['NAME', 'B01003_001E', 'B01002_001E', 'B01002_002E', 'B01002_003E',
#        'B15003_001E', 'B15003_017E', 'B15003_018E', 'B15003_019E',
#        'B15003_020E', 'B15003_021E', 'B15003_022E', 'B15003_023E',
#        'B15003_024E', 'B15003_025E', 'B28002_001E', 'B28002_002E',
#        'B28002_003E', 'B28002_004E', 'B28002_005E', 'B28002_006E',
#        'B28002_007E', 'B28002_008E', 'B28002_009E', 'B28002_010E',
#        'B28002_011E', 'B28002_012E', 'B28002_013E', 'B28003_001E',
#        'B28003_002E', 'B28003_003E', 'B28003_004E', 'B28003_005E',
#        'B28003_006E', 'state', 'county', 'tract', 'S2301_C03_001E',
#        'S1701_C02_001E', 'S1701_C01_001E', 'S1901_C01_012E', 'S1101_C01_001E',
#        'S1101_C01_002E', 'S1101_C01_004E', 'S2701_C03_011E', 'S2701_C03_012E',
#        'S2701_C03_013E', 'DP04_0142PE', 'DP04_0141PE', 'DP05_0001E',
#        'DP04_0089E', 'DP05_0077PE', 'DP05_0071PE', 'DP05_0078PE',
#        'DP05_0079PE', 'DP05_0080PE', 'DP05_0081PE', 'DP05_0082PE',
# ...

# %%
## Need to replace negative census values with NAs

data = data.replace(-1, np.nan)
data = data.replace(-1.0, np.nan)
data = data.replace( -666666666, np.nan)

# %%
data[data.DP04_0142PE == -666666666]
# Out:
# Empty DataFrame
# Columns: [NAME, B01003_001E, B01002_001E, B01002_002E, B01002_003E, B15003_001E, B15003_017E, B15003_018E, B15003_019E, B15003_020E, B15003_021E, B15003_022E, B15003_023E, B15003_024E, B15003_025E, B28002_001E, B28002_002E, B28002_003E, B28002_004E, B28002_005E, B28002_006E, B28002_007E, B28002_008E, B28002_009E, B28002_010E, B28002_011E, B28002_012E, B28002_013E, B28003_001E, B28003_002E, B28003_003E, B28003_004E, B28003_005E, B28003_006E, state, county, tract, S2301_C03_001E, S1701_C02_001E, S1701_C01_001E, S1901_C01_012E, S1101_C01_001E, S1101_C01_002E, S1101_C01_004E, S2701_C03_011E, S2701_C03_012E, S2701_C03_013E, DP04_0142PE, DP04_0141PE, DP05_0001E, DP04_0089E, DP05_0077PE, DP05_0071PE, DP05_0078PE, DP05_0079PE, DP05_0080PE, DP05_0081PE, DP05_0082PE, DP05_0083PE]
# Index: []
#
# [0 rows x 59 columns]

# %% [markdown]
# ## Which columns are more null?

# %%
data[data["B01003_001E"].isna()]
# Out:
# Empty DataFrame
# Columns: [NAME, B01003_001E, B01002_001E, B01002_002E, B01002_003E, B15003_001E, B15003_017E, B15003_018E, B15003_019E, B15003_020E, B15003_021E, B15003_022E, B15003_023E, B15003_024E, B15003_025E, B28002_001E, B28002_002E, B28002_003E, B28002_004E, B28002_005E, B28002_006E, B28002_007E, B28002_008E, B28002_009E, B28002_010E, B28002_011E, B28002_012E, B28002_013E, B28003_001E, B28003_002E, B28003_003E, B28003_004E, B28003_005E, B28003_006E, state, county, tract, S2301_C03_001E, S1701_C02_001E, S1701_C01_001E, S1901_C01_012E, S1101_C01_001E, S1101_C01_002E, S1101_C01_004E, S2701_C03_011E, S2701_C03_012E, S2701_C03_013E, DP04_0142PE, DP04_0141PE, DP05_0001E, DP04_0089E, DP05_0077PE, DP05_0071PE, DP05_0078PE, DP05_0079PE, DP05_0080PE, DP05_0081PE, DP05_0082PE, DP05_0083PE]
# Index: []
#
# [0 rows x 59 columns]

# %%
data[data["DP05_0001E"].isna()]
# Out:
# Empty DataFrame
# Columns: [NAME, B01003_001E, B01002_001E, B01002_002E, B01002_003E, B15003_001E, B15003_017E, B15003_018E, B15003_019E, B15003_020E, B15003_021E, B15003_022E, B15003_023E, B15003_024E, B15003_025E, B28002_001E, B28002_002E, B28002_003E, B28002_004E, B28002_005E, B28002_006E, B28002_007E, B28002_008E, B28002_009E, B28002_010E, B28002_011E, B28002_012E, B28002_013E, B28003_001E, B28003_002E, B28003_003E, B28003_004E, B28003_005E, B28003_006E, state, county, tract, S2301_C03_001E, S1701_C02_001E, S1701_C01_001E, S1901_C01_012E, S1101_C01_001E, S1101_C01_002E, S1101_C01_004E, S2701_C03_011E, S2701_C03_012E, S2701_C03_013E, DP04_0142PE, DP04_0141PE, DP05_0001E, DP04_0089E, DP05_0077PE, DP05_0071PE, DP05_0078PE, DP05_0079PE, DP05_0080PE, DP05_0081PE, DP05_0082PE, DP05_0083PE]
# Index: []
#
# [0 rows x 59 columns]

# %%
#The missing values have very small populations
data[data.median_age_overall.isnull()].total_pop2.value_counts()
# Out:
# 0     646
# 4       7
# 8       3
# 9       3
# 2       2
# 5       2
# 11      2
# 14      2
# 6       1
# 10      1
# 16      1
# 28      1
# 58      1
# Name: total_pop2, dtype: int64

# %% [markdown]
# ## Rename Columns

# %%
## Renaming data columns
data = data.rename(columns = {"B01002_001E" : "median_age_overall", "B01002_002E": "median_age_male", "B01002_003E" : 
                      "median_age_female", "DP05_0001E" : "total_population", "B01003_001E" : "total_pop2",
                              "DP04_0089E" : "median_house_value",
                      "S1901_C01_012E" : "median_income", "S2301_C03_001E" : "employment_rate",
                      "S1101_C01_002E": "ave_household_size", "S1101_C01_004E" : "ave_family_size", "S1101_C01_001E" :
                             "total_households"})

# %% [markdown]
# ## Calculating Additional Data Columns

# %%
np.sum(data["DP04_0142PE"]<0)
# Out:
# 0

# %%
def safe_division(x, y):
    try:
        return (x / y)*100
    except:
        #y would have been 0 so return NAN
        return np.nan

# %%
## Calculating Additional Data Columns
data["pct_rent_burdened"] = data.apply(lambda x:  x["DP04_0142PE"] + x["DP04_0141PE"], axis=1)
data["poverty_rate"] = data.apply(lambda x: safe_division(x["S1701_C02_001E"], x["S1701_C01_001E"]), axis=1)
data["pct_pop_bachelors+"] = data.apply(lambda x: safe_division((x["B15003_022E"] + x["B15003_023E"] + x["B15003_024E"] +
                                                 x["B15003_025E"]), x["B15003_001E"]), axis=1)
data["pct_pop_hs+"] = data.apply(lambda x: x["pct_pop_bachelors+"] + safe_division(( x["B15003_018E"] + x["B15003_019E"] + 
                                            x["B15003_020E"] + x["B15003_021E"]), x["B15003_001E"]), axis=1)

## Internet Statistics
data["pct_internet"] = data.apply(lambda x: safe_division(x["B28002_002E"] , x["B28002_001E"]), axis=1)
data["pct_internet_dial_up"]= data.apply(lambda x: safe_division(x["B28002_003E"] , x["B28002_001E"]), axis=1)
data["pct_internet_broadband_any_type"]= data.apply(lambda x: safe_division(x["B28002_004E"] , x["B28002_001E"]), axis=1)
data["pct_internet_cellular"]= data.apply(lambda x: safe_division(x["B28002_005E"] , x["B28002_001E"]), axis=1)
data["pct_only_cellular"]= data.apply(lambda x: safe_division(x["B28002_006E"] , x["B28002_001E"]), axis=1)
data["pct_internet_broadband_fiber"]= data.apply(lambda x: safe_division(x["B28002_008E"] , x["B28002_001E"]), axis=1)
data["pct_internet_broadband_satellite"]= data.apply(lambda x: safe_division(x["B28002_009E"] , x["B28002_001E"]), axis=1)
data["pct_internet_only_satellite"]= data.apply(lambda x: safe_division(x["B28002_010E"] , x["B28002_001E"]), axis=1)
data["pct_internet_other"]= data.apply(lambda x: safe_division(x["B28002_011E"] , x["B28002_001E"]), axis=1)
data["pct_internet_no_subscrp"]= data.apply(lambda x: safe_division(x["B28002_012E"] , x["B28002_001E"]), axis=1)
data["pct_internet_none"]= data.apply(lambda x: safe_division(x["B28002_013E"] , x["B28002_001E"]), axis=1)


## Computer Statistics
data["pct_computer"] = data.apply(lambda x: safe_division(x["B28003_002E"] , x["B28003_001E"]), axis=1)
data["pct_computer_with_dialup"] = data.apply(lambda x: safe_division(x["B28003_003E"] , x["B28003_001E"]), axis=1)
data["pct_computer_with_broadband"] = data.apply(lambda x: safe_division(x["B28003_004E"] , x["B28003_001E"]), axis=1)
data["pct_computer_no_internet"] = data.apply(lambda x: safe_division(x["B28003_005E"] , x["B28003_001E"]), axis=1)
data["pct_no_computer"] = data.apply(lambda x: safe_division(x["B28003_006E"] , x["B28003_001E"]), axis=1)

# %%
## Race/Ethnicity Statistics To Rename

data = data.rename(columns = {"DP05_0077PE" : "pct_white", "DP05_0071PE" : "pct_hisp_latino", "DP05_0078PE" :
                             "pct_black", "DP05_0079PE" : "pct_native", "DP05_0080PE" : "pct_asian", "DP05_0081PE" :
                             "pct_hi_pi", "DP05_0082PE" : "pct_other_race", "DP05_0083PE" : "pct_two+_race"})

# %%
## Health Insurance Statistics to Rename

data = data.rename(columns = {"S2701_C03_011E" : "pct_health_ins_children", "S2701_C03_012E" :
                              "pct_health_ins_19_64", "S2701_C03_013E" : "pct_health_ins_65+"
    
})

# %%
cols_to_drop = []
for col in data.columns:
    if col.startswith("DP"):
        cols_to_drop.append(col)
    elif col.startswith("B"):
        cols_to_drop.append(col)
    elif col.startswith("S"):
        cols_to_drop.append(col)
        
cols_to_drop
# Out:
# ['B15003_001E',
#  'B15003_017E',
#  'B15003_018E',
#  'B15003_019E',
#  'B15003_020E',
#  'B15003_021E',
#  'B15003_022E',
#  'B15003_023E',
#  'B15003_024E',
#  'B15003_025E',
#  'B28002_001E',
#  'B28002_002E',
#  'B28002_003E',
#  'B28002_004E',
#  'B28002_005E',
#  'B28002_006E',
#  'B28002_007E',
#  'B28002_008E',
#  'B28002_009E',
#  'B28002_010E',
#  'B28002_011E',
#  'B28002_012E',
#  'B28002_013E',
#  'B28003_001E',
#  'B28003_002E',
#  'B28003_003E',
#  'B28003_004E',
#  'B28003_005E',
#  'B28003_006E',
#  'S1701_C02_001E',
#  'S1701_C01_001E',
#  'DP04_0142PE',
#  'DP04_0141PE']

# %%
new_data = data.drop(columns=cols_to_drop)
new_data.columns
# Out:
# Index(['NAME', 'total_pop2', 'median_age_overall', 'median_age_male',
#        'median_age_female', 'state', 'county', 'tract', 'employment_rate',
#        'median_income', 'total_households', 'ave_household_size',
#        'ave_family_size', 'pct_health_ins_children', 'pct_health_ins_19_64',
#        'pct_health_ins_65+', 'total_population', 'median_house_value',
#        'pct_white', 'pct_hisp_latino', 'pct_black', 'pct_native', 'pct_asian',
#        'pct_hi_pi', 'pct_other_race', 'pct_two+_race', 'pct_rent_burdened',
#        'poverty_rate', 'pct_pop_bachelors+', 'pct_pop_hs+', 'pct_internet',
#        'pct_internet_dial_up', 'pct_internet_broadband_any_type',
#        'pct_internet_cellular', 'pct_only_cellular',
#        'pct_internet_broadband_fiber', 'pct_internet_broadband_satellite',
#        'pct_internet_only_satellite', 'pct_internet_other',
#        'pct_internet_no_subscrp', 'pct_internet_none', 'pct_computer',
# ...

# %%
new_data.to_csv("../data/relabeled_census.csv",index=False)

# %% [markdown]
# ## Data Cleaning Part 2
# On additional data colleced on 2/22

# %%
data = pd.read_csv("../data/additional_census_data_2_22.csv")
data
# Out:
#                                                     NAME  B15003_001E  \
# 0             Census Tract 11, Jefferson County, Alabama       3285.0
# 1             Census Tract 14, Jefferson County, Alabama       1274.0
# 2             Census Tract 20, Jefferson County, Alabama       2802.0
# 3          Census Tract 38.02, Jefferson County, Alabama       3464.0
# 4             Census Tract 40, Jefferson County, Alabama       1971.0
# ...                                                  ...          ...
# 73051  Census Tract 215, Hillsborough County, New Ham...       3728.0
# 73052  Census Tract 1.02, Hillsborough County, New Ha...       3335.0
# 73053  Census Tract 14, Hillsborough County, New Hamp...       1514.0
# 73054  Census Tract 106, Hillsborough County, New Ham...       3817.0
# 73055  Census Tract 114.02, Hillsborough County, New ...       3553.0
#
#        B15003_015E  B15003_016E  B15003_017E  B15003_018E  B15003_019E  \
# ...

# %%
np.unique(data.state).shape
# Out:
# (51,)

# %%
data.isnull().sum()
# Out:
# NAME                  0
# B15003_001E       10137
# B15003_015E       10137
# B15003_016E       10137
# B15003_017E       10137
#                   ...
# S1810_C01_055E      295
# S1810_C01_063E      295
# S1810_C02_001E      295
# S1101_C01_010E      295
# S1101_C01_009E      295
# Length: 66, dtype: int64

# %%
data[data.B15003_001E.isna()].state.value_counts()
# Out:
# 34    2010
# 4     1526
# 18    1511
# 25    1478
# 24    1406
# 32     687
# 54     484
# 15     351
# 44     244
# 46     222
# 10     218
# Name: state, dtype: int64

# %%
data[data.S1810_C01_055E.isna()].state.value_counts()
# Out:
# 33    295
# Name: state, dtype: int64

# %%
data3 = pd.read_csv("../data/additional_data_v3.csv")
data3.head()
# Out:
#                                                 NAME  B15003_001E  \
# 0  Census Tract 5012.10, Gloucester County, New J...         2417
# 1  Census Tract 5013.01, Gloucester County, New J...         2490
# 2  Census Tract 5013.03, Gloucester County, New J...         1843
# 3   Census Tract 5019, Gloucester County, New Jersey         2990
# 4   Census Tract 5003, Gloucester County, New Jersey         2052
#
#    B15003_015E  B15003_016E  B15003_017E  B15003_018E  B15003_019E  \
# 0           26           36          579           97          138
# 1            9           28          435           89          210
# 2           45           12          458           30           53
# 3           70          134          712          187          255
# 4           32           34          771          117          180
#
#    B15003_020E  B15003_021E  B15003_022E  ...  S1810_C01_001E  S1810_C01_019E  \
# 0          327          224          579  ...             NaN             NaN
# ...

# %%
data3.state.value_counts()
# Out:
# 34    2010
# 18    1511
# 54     484
# 15     351
# 46     222
# Name: state, dtype: int64

# %%
data3[data3.B15003_001E.isna()].state.value_counts()
# Out:
# Series([], Name: state, dtype: int64)

# %%
data3[data3.S1810_C01_055E.isna()].state.value_counts()
# Out:
# 34    2010
# Name: state, dtype: int64

# %%
data2 = pd.read_csv("../data/additional_data_v2.csv")
data2.state.value_counts()
# Out:
# 34    2010
# 25    1478
# 24    1406
# 32     687
# 15     351
# 33     295
# 10     218
# Name: state, dtype: int64

# %%
data2[data2.B15003_001E.isna()].state.value_counts()
# Out:
# 15    351
# Name: state, dtype: int64

# %%
data2[data2.S1810_C01_055E.isna()].state.value_counts()
# Out:
# 34    2010
# 10     218
# Name: state, dtype: int64

# %%
data4 = pd.read_csv("../data/additional_data_v4.csv")
data4.state.value_counts()
# Out:
# 34    2010
# 4     1526
# 44     244
# 10     218
# Name: state, dtype: int64

# %%
data4[data4.B15003_001E.isna()].state.value_counts()
# Out:
# Series([], Name: state, dtype: int64)

# %%
data4[data4.S1810_C01_055E.isna()].state.value_counts()
# Out:
# Series([], Name: state, dtype: int64)

# %%
#Filter to just rows where state is not 34, 4, 44, 10
new_data = data[data.state!=4]
new_data = new_data[new_data.state!=34]
new_data = new_data[new_data.state!=44]
new_data = new_data[new_data.state!=10]

# %%
big_data = pd.concat([new_data, data4], ignore_index=True)

# %%
big_data[big_data.B15003_001E.isna()].state.value_counts()
# Out:
# 18    1511
# 25    1478
# 24    1406
# 32     687
# 54     484
# 15     351
# 46     222
# Name: state, dtype: int64

# %%
#Now drop other missing rows
big_data = big_data[big_data.state!=18]
big_data = big_data[big_data.state!=54]
big_data = big_data[big_data.state!=46]
big_data = big_data[big_data.state!=15]

#And drop 34 from data3 since got from data4
data3 = data3[data3.state!=34]

# %%
big_data = pd.concat([big_data, data3], ignore_index=True)

# %%
big_data[big_data.B15003_001E.isna()].state.value_counts()
# Out:
# 25    1478
# 24    1406
# 32     687
# Name: state, dtype: int64

# %%
big_data[big_data.S1810_C01_055E.isna()].state.value_counts()
# Out:
# 33    295
# Name: state, dtype: int64

# %%
#Now drop other missing rows
big_data = big_data[big_data.state!=25]
big_data = big_data[big_data.state!=24]
big_data = big_data[big_data.state!=32]
big_data = big_data[big_data.state!=33]

#And only take these from data2
these = [25, 24, 32, 33]
data2 = data2[data2.state.isin(these)]

big_data = pd.concat([big_data, data2], ignore_index=True)

# %%
big_data[big_data.B15003_001E.isna()].state.value_counts()
# Out:
# Series([], Name: state, dtype: int64)

# %%
big_data[big_data.S1810_C01_055E.isna()].state.value_counts()
# Out:
# Series([], Name: state, dtype: int64)

# %%
np.unique(big_data.state).shape
# Out:
# (51,)

# %%
pd.set_option('display.max_rows', None)
big_data.isnull().sum()
# Out:
# NAME                  0
# B15003_001E           0
# B15003_015E           0
# B15003_016E           0
# B15003_017E           0
# B15003_018E           0
# B15003_019E           0
# B15003_020E           0
# B15003_021E           0
# B15003_022E           0
# B15003_023E           0
# B15003_024E           0
# B15003_025E           0
# B05004_001E         672
# B05004_007E        6024
# B09010_001E           0
# B09010_002E           0
# B19001_001E           0
# B19001_002E           0
# B19001_003E           0
# B19001_004E           0
# B19001_005E           0
# B19001_006E           0
# B19001_007E           0
# B19001_008E           0
# B19001_009E           0
# B19001_010E           0
# B19001_011E           0
# B19001_012E           0
# B19001_013E           0
# B19001_014E           0
# B19001_015E           0
# B19001_016E           0
# B19001_017E           0
# state                 0
# county                0
# tract                 0
# S0101_C01_001E        0
# ...

# %%
big_data = big_data.replace(-1, np.nan)
big_data = big_data.replace(-666666666, np.nan)
big_data = big_data.replace(-888888888, np.nan)
big_data = big_data.replace(-666666666.0, np.nan)

# %%
big_data.to_csv("../data/aggregated_census_2_22.csv", index_label=False)

# %% [markdown]
# ## DATA cleaning Part 2

# %%
big_data = pd.read_csv("../data/aggregated_census_2_22.csv")

# %%
big_data.head()
# Out:
#                                             NAME  B15003_001E  B15003_015E  \
# 0     Census Tract 11, Jefferson County, Alabama       3285.0         23.0
# 1     Census Tract 14, Jefferson County, Alabama       1274.0         82.0
# 2     Census Tract 20, Jefferson County, Alabama       2802.0        219.0
# 3  Census Tract 38.02, Jefferson County, Alabama       3464.0        119.0
# 4     Census Tract 40, Jefferson County, Alabama       1971.0         81.0
#
#    B15003_016E  B15003_017E  B15003_018E  B15003_019E  B15003_020E  \
# 0         47.0        552.0        201.0        269.0        534.0
# 1         36.0        300.0         15.0         57.0        399.0
# 2         92.0        720.0        134.0        267.0        571.0
# 3        139.0       1294.0         32.0        221.0        551.0
# 4         56.0        540.0        144.0        130.0        509.0
#
#    B15003_021E  B15003_022E  ...  S1810_C01_001E  S1810_C01_019E  \
# ...

# %%
big_data.columns
# Out:
# Index(['NAME', 'B15003_001E', 'B15003_015E', 'B15003_016E', 'B15003_017E',
#        'B15003_018E', 'B15003_019E', 'B15003_020E', 'B15003_021E',
#        'B15003_022E', 'B15003_023E', 'B15003_024E', 'B15003_025E',
#        'B05004_001E', 'B05004_007E', 'B09010_001E', 'B09010_002E',
#        'B19001_001E', 'B19001_002E', 'B19001_003E', 'B19001_004E',
#        'B19001_005E', 'B19001_006E', 'B19001_007E', 'B19001_008E',
#        'B19001_009E', 'B19001_010E', 'B19001_011E', 'B19001_012E',
#        'B19001_013E', 'B19001_014E', 'B19001_015E', 'B19001_016E',
#        'B19001_017E', 'state', 'county', 'tract', 'S0101_C01_001E',
#        'S0101_C01_002E', 'S0101_C01_003E', 'S0101_C01_004E', 'S0101_C01_005E',
#        'S0101_C01_006E', 'S0101_C01_007E', 'S0101_C01_008E', 'S0101_C01_009E',
#        'S0101_C01_010E', 'S0101_C01_011E', 'S0101_C01_012E', 'S0101_C01_013E',
#        'S0101_C01_014E', 'S0101_C01_015E', 'S0101_C01_016E', 'S0101_C01_017E',
# ...

# %%
## More educational statistics
big_data["pct_pop_ged"] = big_data.apply(lambda x: safe_division((x["B15003_018E"]), x["B15003_001E"]), axis=1)
big_data["pct_pop_some_college"] = big_data.apply(lambda x: safe_division((x["B15003_019E"] + x["B15003_020E"]), x["B15003_001E"]), axis=1)
big_data["pct_pop_associates"] = big_data.apply(lambda x: safe_division((x["B15003_021E"]), x["B15003_001E"]), axis=1)


## Foreign born
big_data["pct_pop_foreign_born"] = big_data.apply(lambda x: safe_division((x["B05004_007E"]), x["B05004_001E"]), axis=1)

## RECEIPT OF SUPPLEMENTAL SECURITY INCOME (SSI), CASH PUBLIC ASSISTANCE INCOME, OR FOOD STAMPS/SNAP IN THE PAST 12 MONTHS
## BY HOUSEHOLD TYPE FOR CHILDREN UNDER 18 YEARS IN HOUSEHOLDS

big_data["pct_pop_ssi_households"] = big_data.apply(lambda x: safe_division((x["B09010_002E"]), x["B09010_001E"]), axis=1)

## Household income groups
big_data["pct_pop_lt_10k"] = big_data.apply(lambda x: safe_division((x["B19001_002E"]), x["B19001_001E"]), axis=1)
big_data["pct_pop_10k_thru_15k"] = big_data.apply(lambda x: safe_division((x["B19001_003E"]), x["B19001_001E"]), axis=1)
big_data["pct_pop_15k_thru_20k"] = big_data.apply(lambda x: safe_division((x["B19001_004E"]), x["B19001_001E"]), axis=1)
big_data["pct_pop_20k_thru_25k"] = big_data.apply(lambda x: safe_division((x["B19001_005E"]), x["B19001_001E"]), axis=1)
big_data["pct_pop_25k_thru_30k"] = big_data.apply(lambda x: safe_division((x["B19001_006E"]), x["B19001_001E"]), axis=1)
big_data["pct_pop_30k_thru_35k"] = big_data.apply(lambda x: safe_division((x["B19001_007E"]), x["B19001_001E"]), axis=1)
big_data["pct_pop_35k_thru_40k"] = big_data.apply(lambda x: safe_division((x["B19001_008E"]), x["B19001_001E"]), axis=1)
big_data["pct_pop_40k_thru_45k"] = big_data.apply(lambda x: safe_division((x["B19001_009E"]), x["B19001_001E"]), axis=1)
big_data["pct_pop_45k_thru_50k"] = big_data.apply(lambda x: safe_division((x["B19001_010E"]), x["B19001_001E"]), axis=1)
big_data["pct_pop_50k_thru_60k"] = big_data.apply(lambda x: safe_division((x["B19001_011E"]), x["B19001_001E"]), axis=1)
big_data["pct_pop_60k_thru_75k"] = big_data.apply(lambda x: safe_division((x["B19001_012E"]), x["B19001_001E"]), axis=1)
big_data["pct_pop_75k_thru_100k"] = big_data.apply(lambda x: safe_division((x["B19001_013E"]), x["B19001_001E"]), axis=1)
big_data["pct_pop_100k_thru_125k"] = big_data.apply(lambda x: safe_division((x["B19001_014E"]), x["B19001_001E"]), axis=1)
big_data["pct_pop_125k_thru_150k"] = big_data.apply(lambda x: safe_division((x["B19001_015E"]), x["B19001_001E"]), axis=1)
big_data["pct_pop_150k_thru_200k"] = big_data.apply(lambda x: safe_division((x["B19001_016E"]), x["B19001_001E"]), axis=1)
big_data["pct_pop_gt_200k"] = big_data.apply(lambda x: safe_division((x["B19001_017E"]), x["B19001_001E"]), axis=1)

# %%
## Age groups
big_data["pct_pop_lt_5"] = big_data.apply(lambda x: safe_division((x["S0101_C01_002E"]), x["S0101_C01_001E"]), axis=1)
big_data["pct_pop_5_to_9"] = big_data.apply(lambda x: safe_division((x["S0101_C01_003E"]), x["S0101_C01_001E"]), axis=1)
big_data["pct_pop_10_to_14"] = big_data.apply(lambda x: safe_division((x["S0101_C01_004E"]), x["S0101_C01_001E"]), axis=1)
big_data["pct_pop_15_to_19"] = big_data.apply(lambda x: safe_division((x["S0101_C01_005E"]), x["S0101_C01_001E"]), axis=1)
big_data["pct_pop_20_to_24"] = big_data.apply(lambda x: safe_division((x["S0101_C01_006E"]), x["S0101_C01_001E"]), axis=1)
big_data["pct_pop_25_to_29"] = big_data.apply(lambda x: safe_division((x["S0101_C01_007E"]), x["S0101_C01_001E"]), axis=1)
big_data["pct_pop_30_to_34"] = big_data.apply(lambda x: safe_division((x["S0101_C01_008E"]), x["S0101_C01_001E"]), axis=1)
big_data["pct_pop_35_to_39"] = big_data.apply(lambda x: safe_division((x["S0101_C01_009E"]), x["S0101_C01_001E"]), axis=1)
big_data["pct_pop_40_to_44"] = big_data.apply(lambda x: safe_division((x["S0101_C01_010E"]), x["S0101_C01_001E"]), axis=1)
big_data["pct_pop_45_to_49"] = big_data.apply(lambda x: safe_division((x["S0101_C01_011E"]), x["S0101_C01_001E"]), axis=1)
big_data["pct_pop_50_to_54"] = big_data.apply(lambda x: safe_division((x["S0101_C01_012E"]), x["S0101_C01_001E"]), axis=1)
big_data["pct_pop_55_to_59"] = big_data.apply(lambda x: safe_division((x["S0101_C01_013E"]), x["S0101_C01_001E"]), axis=1)
big_data["pct_pop_60_to_64"] = big_data.apply(lambda x: safe_division((x["S0101_C01_014E"]), x["S0101_C01_001E"]), axis=1)
big_data["pct_pop_65_to_69"] = big_data.apply(lambda x: safe_division((x["S0101_C01_015E"]), x["S0101_C01_001E"]), axis=1)
big_data["pct_pop_70_to_74"] = big_data.apply(lambda x: safe_division((x["S0101_C01_016E"]), x["S0101_C01_001E"]), axis=1)
big_data["pct_pop_75_to_79"] = big_data.apply(lambda x: safe_division((x["S0101_C01_017E"]), x["S0101_C01_001E"]), axis=1)
big_data["pct_pop_80_to_84"] = big_data.apply(lambda x: safe_division((x["S0101_C01_018E"]), x["S0101_C01_001E"]), axis=1)
big_data["pct_pop_gt_85"] = big_data.apply(lambda x: safe_division((x["S0101_C01_019E"]), x["S0101_C01_001E"]), axis=1)


## Disability
big_data["pct_pop_disability"] = big_data.apply(lambda x: safe_division((x["S1810_C02_001E"]), x["S1810_C01_001E"]), axis=1)


## households with people < 18
big_data["pct_pop_households_with_kids"] = big_data.apply(lambda x: safe_division((x["S1101_C01_010E"]), x["S1101_C01_009E"]), axis=1)

# %%
cols_to_keep = ['state', 'tract', 'county']

for col in big_data.columns:
    if col.startswith("pct_"):
        cols_to_keep.append(col)

# %%
fcc = pd.read_csv("../data/fcc_census.csv")
fcc.head()
# Out:
#    tract_geoid  All_Provider_Count  \
# 0   1001020100                   7
# 1   1001020200                  10
# 2   1001020300                  10
# 3   1001020400                   8
# 4   1001020500                  13
#
#                                        All_Providers  MaxAdDown  MaxAdUp  \
# 0  {56004, 58757, 54694, 67056, 59349, 55262, 58623}     1000.0     50.0
# 1  {56004, 58757, 54694, 67056, 59349, 56888, 555...     1000.0     50.0
# 2  {56004, 58757, 54694, 67056, 59349, 56888, 555...     1000.0     50.0
# 3  {56004, 58757, 54694, 67056, 59349, 55514, 552...     1000.0     50.0
# 4  {56004, 58757, 54694, 56170, 54860, 54927, 670...     1000.0   1000.0
#
#                                         AllMaxAdDown  \
# 0  {0.0, 0.768, 1.5, 3.0, 100.0, 2.0, 6.0, 1000.0...
# 1  {0.0, 1.5, 2.0, 3.0, 100.0, 6.0, 1000.0, 10.0,...
# 2  {0.0, 2.0, 100.0, 6.0, 1000.0, 940.0, 12.0, 18...
# 3  {0.0, 0.768, 1.5, 3.0, 100.0, 5.0, 6.0, 2.0, 1...
# ...

# %%
cols_to_keep
# Out:
# ['state',
#  'tract',
#  'county',
#  'pct_pop_ged',
#  'pct_pop_some_college',
#  'pct_pop_associates',
#  'pct_pop_foreign_born',
#  'pct_pop_ssi_households',
#  'pct_pop_lt_10k',
#  'pct_pop_10k_thru_15k',
#  'pct_pop_15k_thru_20k',
#  'pct_pop_20k_thru_25k',
#  'pct_pop_25k_thru_30k',
#  'pct_pop_30k_thru_35k',
#  'pct_pop_35k_thru_40k',
#  'pct_pop_40k_thru_45k',
#  'pct_pop_45k_thru_50k',
#  'pct_pop_50k_thru_60k',
#  'pct_pop_60k_thru_75k',
#  'pct_pop_75k_thru_100k',
#  'pct_pop_100k_thru_125k',
#  'pct_pop_125k_thru_150k',
#  'pct_pop_150k_thru_200k',
#  'pct_pop_gt_200k',
#  'pct_pop_lt_5',
#  'pct_pop_5_to_9',
#  'pct_pop_10_to_14',
#  'pct_pop_15_to_19',
#  'pct_pop_20_to_24',
#  'pct_pop_25_to_29',
#  'pct_pop_30_to_34',
#  'pct_pop_35_to_39',
#  'pct_pop_40_to_44',
#  'pct_pop_45_to_49',
#  'pct_pop_50_to_54',
#  'pct_pop_55_to_59',
#  'pct_pop_60_to_64',
#  'pct_pop_65_to_69',
#  'pct_pop_70_to_74',
#  'pct_pop_75_to_79',
#  'pct_pop_80_to_84',
#  'pct_pop_gt_85',
# ...

# %%
df = fcc.merge(big_data[cols_to_keep], on = ['state', 'tract', 'county'], how='outer')

# %%
df.columns
# Out:
# Index(['tract_geoid', 'All_Provider_Count', 'All_Providers', 'MaxAdDown',
#        'MaxAdUp', 'AllMaxAdDown', 'AllMaxAdUp', 'Wired_Provider_Count',
#        'Satellite_Provider_Count', 'Fixed_Wireless_Provider_Count',
#        ...
#        'pct_pop_50_to_54', 'pct_pop_55_to_59', 'pct_pop_60_to_64',
#        'pct_pop_65_to_69', 'pct_pop_70_to_74', 'pct_pop_75_to_79',
#        'pct_pop_80_to_84', 'pct_pop_gt_85', 'pct_pop_disability',
#        'pct_pop_households_with_kids'],
#       dtype='object', length=111)

# %%
df.shape
# Out:
# (73056, 111)

# %%
df.isnull().sum()
# Out:
# tract_geoid                             0
# All_Provider_Count                      0
# All_Providers                           0
# MaxAdDown                               0
# MaxAdUp                                 0
# AllMaxAdDown                            0
# AllMaxAdUp                              0
# Wired_Provider_Count                    0
# Satellite_Provider_Count                0
# Fixed_Wireless_Provider_Count           0
# All_Provider_Count_25                   0
# All_Provider_Count_100                  0
# Fixed_Wireless_Provider_Count_25        0
# Wired_Provider_Count_25                 0
# Satellite_Provider_Count_25             0
# Fixed_Wireless_Provider_Count_100       0
# Wired_Provider_Count_100                0
# Satellite_Provider_Count_100            0
# NAME                                    0
# total_pop2                              0
# median_age_overall                    672
# median_age_male                       702
# ...

# %%
nbam = pd.read_csv("../data/nbam/IBNTracts.csv")

# %%
nbam.shape
# Out:
# (73767, 17)

# %%
nbam.head()
# Out:
#    Geographic Identifier - FIPS Code                 Name   State  \
# 0                        15001020100     Census Tract 201  Hawaii
# 1                        15001020202  Census Tract 202.02  Hawaii
# 2                        15001020300     Census Tract 203  Hawaii
# 3                        15001020400     Census Tract 204  Hawaii
# 4                        15001020500     Census Tract 205  Hawaii
#
#           County  Total households  Total households - Margin of Error  \
# 0  Hawaii County            1620.0                               148.0
# 1  Hawaii County             651.0                                73.0
# 2  Hawaii County            1698.0                               127.0
# 3  Hawaii County            1300.0                               131.0
# 4  Hawaii County            2130.0                               206.0
#
#    Percent of Households that Have No Computer, Smartphone, or Tablet  \
# 0                                               20.9
# ...

# %%
nbam.columns
# Out:
# Index(['Geographic Identifier - FIPS Code', 'Name', 'State', 'County',
#        'Total households', 'Total households - Margin of Error',
#        'Percent of Households that Have No Computer, Smartphone, or Tablet',
#        'Percent of Households that Have No Computer, Smartphone, or Tablet - Margin of Error',
#        'Percent of Households with No Internet Access',
#        'Percent of Households with No Internet Access - Margin of Error',
#        'Percent of Population whose income in the past 12 months is below poverty level',
#        'Percent of Population whose income in the past 12 months is below poverty level - Margin of Error',
#        'Form 477 All Terrestrial Broadband: Max Advertised Consumer Download Speed (Mbps)',
#        'Form 477 All Terrestrial Broadband: Max Advertised Consumer Upload Speed (Mbps)',
#        'Ookla Median Download Speed (Mbps)',
#        'Ookla Median Upload Speed (Mbps)', 'Population 2019 (FCC Estimate)'],
#       dtype='object')

# %%
df = df.merge(nbam[['Geographic Identifier - FIPS Code', 'Ookla Median Download Speed (Mbps)',
       'Ookla Median Upload Speed (Mbps)']], left_on = 'tract_geoid', right_on = 'Geographic Identifier - FIPS Code', how='left')

# %%
df.isnull().sum()
# Out:
# tract_geoid                              0
# All_Provider_Count                       0
# All_Providers                            0
# MaxAdDown                                0
# MaxAdUp                                  0
# AllMaxAdDown                             0
# AllMaxAdUp                               0
# Wired_Provider_Count                     0
# Satellite_Provider_Count                 0
# Fixed_Wireless_Provider_Count            0
# All_Provider_Count_25                    0
# All_Provider_Count_100                   0
# Fixed_Wireless_Provider_Count_25         0
# Wired_Provider_Count_25                  0
# Satellite_Provider_Count_25              0
# Fixed_Wireless_Provider_Count_100        0
# Wired_Provider_Count_100                 0
# Satellite_Provider_Count_100             0
# NAME                                     0
# total_pop2                               0
# median_age_overall                     672
# median_age_male                        702
# ...

# %%
df[df['Geographic Identifier - FIPS Code'].isna()][['NAME', 'state', 'total_pop2']]
# Out:
#                                                     NAME  state  total_pop2
# 43            Census Tract 9900, Baldwin County, Alabama    1.0         0.0
# 868            Census Tract 9900, Mobile County, Alabama    1.0         0.0
# 3920       Census Tract 9900, Alameda County, California    6.0         0.0
# 4204   Census Tract 9900, Contra Costa County, Califo...    6.0         0.0
# 4212     Census Tract 9900, Del Norte County, California    6.0         0.0
# 4255     Census Tract 9900, El Dorado County, California    6.0         0.0
# 4491      Census Tract 9901, Humboldt County, California    6.0         0.0
# 7074   Census Tract 9901, Los Angeles County, California    6.0         0.0
# 7075   Census Tract 9902, Los Angeles County, California    6.0         0.0
# 7076   Census Tract 9903, Los Angeles County, California    6.0         0.0
# 7155         Census Tract 9901, Marin County, California    6.0         0.0
# ...

# %%
df = df.drop(columns=['total_pop2', 'GEOID', 'Geographic Identifier - FIPS Code'])

# %%
df.columns
# Out:
# Index(['tract_geoid', 'All_Provider_Count', 'All_Providers', 'MaxAdDown',
#        'MaxAdUp', 'AllMaxAdDown', 'AllMaxAdUp', 'Wired_Provider_Count',
#        'Satellite_Provider_Count', 'Fixed_Wireless_Provider_Count',
#        ...
#        'pct_pop_60_to_64', 'pct_pop_65_to_69', 'pct_pop_70_to_74',
#        'pct_pop_75_to_79', 'pct_pop_80_to_84', 'pct_pop_gt_85',
#        'pct_pop_disability', 'pct_pop_households_with_kids',
#        'Ookla Median Download Speed (Mbps)',
#        'Ookla Median Upload Speed (Mbps)'],
#       dtype='object', length=111)

# %%
df.to_csv("../data/fcc_census_2.csv", index_label=False)
